# %%
ls
# Out:
# kb_data/  kb_main.csv  kb_main_analyse.ipynb  kb_main_word2vec.ipynb

# %%
ls kb_data/
# Out:
# kb_data.rar            kb_main_dialog.csv          kb_main_index_bak.csv
# kb_main.csv            kb_main_import.csv          kb_main_log.csv
# kb_main_20180112.csv   kb_main_import_detail.csv   kb_main_question.csv
# kb_main_201801121.csv  kb_main_index.csv           kb_tree.csv
# kb_main_atta.csv       kb_main_index_20171107.csv

# %%
# cd kb_data/
# !cd ..

# %%
# !ls
# !rar x kb_data.rar
# Out:
# kb_data.rar	       kb_main_dialog.csv	   kb_main_index_bak.csv
# kb_main.csv	       kb_main_import.csv	   kb_main_log.csv
# kb_main_20180112.csv   kb_main_import_detail.csv   kb_main_question.csv
# kb_main_201801121.csv  kb_main_index.csv	   kb_tree.csv
# kb_main_atta.csv       kb_main_index_20171107.csv

# %%
import pandas as pd
import jieba,os,re
from gensim import corpora, models, similarities

# %%
root_path='kb_data/'

# %%
df_kb_main=pd.read_csv(root_path+'kb_main.csv')#
df_kb_main_20180112=pd.read_csv(root_path+'kb_main_20180112.csv')#
df_kb_main_201801121=pd.read_csv(root_path+'kb_main_201801121.csv')#
# df_kb_main_atta=pd.read_csv(root_path+'kb_main_atta.csv')
# df_kb_main_dialog=pd.read_csv(root_path+'kb_main_dialog.csv')
# df_kb_main_import=pd.read_csv(root_path+'kb_main_import.csv')
df_kb_main_import_detail=pd.read_csv(root_path+'kb_main_import_detail.csv')#ktype不一样

# df_kb_main_index=pd.read_csv(root_path+'kb_main_index.csv')##词语
# df_kb_main_index_20171107=pd.read_csv(root_path+'kb_main_index_20171107.csv')##词语
# df_kb_main_index_bak=pd.read_csv(root_path+'kb_main_index_bak.csv')##词语
# df_kb_main_log=pd.read_csv(root_path+'kb_main_log.csv')
# df_kb_main_question=pd.read_csv(root_path+'kb_main_question.csv')
# df_kb_tree=pd.read_csv(root_path+'kb_tree.csv')

# %%
df_all=df_kb_main.append(df_kb_main_20180112)
df_all=df_all.append(df_kb_main_201801121)
df_all=df_all.append(df_kb_main_import_detail)
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df_all.sample(20)
# Out:
#                                               kb_content  \
# 18834                                               行政检查
# 10370  <span style='font-weight:bold;'>第八届中国-东盟（泰国）商品...
# 13708                    拱北海关监督电话（链接至拱北海关网站）或12360海关服务热线
# 1493                               各直属海关咨询电话或12360海关服务热线
# 13472  <span style='font-weight:bold;'>第八届中国-东盟（泰国）商品...
# 10415  <table class="comp_tb prd_tb" border="0" cells...
# 20946  <p>对应模块： 企业综合信息——药交所。</p><p>访问地址：http://bi.ami...
# 3585   <span style='font-weight:bold;'>第三十一届中国（广州）国际家...
# 12928  <span style='font-weight:bold;'>第二届中国品牌商品非洲展</...
# 18035  <div class="blkContainerPblk">&#13;\n         ...
# 18719                            各直属海关、隶属海关负责跨境电子商务业务的部门
# 19348  <span style='font-weight:bold;'>2017美国拉斯维加斯国际大...
# 3675   设立时审核企业提交的书面材料和证件，包括以下内容：<br>\n1．申请企业应经工商行政管理部...
# 512    <p><br></p>\n<p>企业IC卡用于证实使用人的身份和进行电子签名，涉及系统安全和...
# 204         <p>我是个积极向上的好宝宝，爱好当然是不断学习，不断给自己充电啦~&nbsp;</p>
# 15133  <span style='font-weight:bold;'>2017 意大利加答国际鞋展...
# 15018  <span style='font-weight:bold;'>第22届华南国际印刷工业展览...
# 23694  <table class="comp_tb prd_tb" border="0" cells...
# 7189   <table class="comp_tb prd_tb" border="0" cells...
# 523    2014美国拉斯维加斯国际家用纺织品及家居饰品展<br/>举办地点：拉斯维加斯会议展览中心<...
#
#                           kb_index                          kb_title  kb_type  \
# 18834  ,hMDIvn8z,tjd2C1HK,1M4diJwZ                保税物流中心的货物管理是什么事项类型   1001.0
# 10370                          NaN               第八届中国-东盟（泰国）商品贸易展览会   1001.0
# 13708  ,YzOuuHqv,pFSTp82u,GjmHl0GT                横琴新区电子账册业务的监督电话是什么   1001.0
# 1493                           NaN              加工贸易企业联网监管业务的咨询电话是什么      NaN
# 13472                          NaN               第八届中国-东盟（泰国）商品贸易展览会   1001.0
# 10415                          NaN   兴业银行-万利宝2018年第1期非保本浮动收益封闭式40009   1001.0
# 20946                          NaN                 如何进行进口药品器械国内物流追踪？   1001.0
# 3585                           NaN        第三十一届中国（广州）国际家具博览会 - 办公环境展   1001.0
# 12928                          NaN                      第二届中国品牌商品非洲展   1001.0
# 18035                          NaN                 邮储银行-云南：悦享分期，感恩有您   1001.0
# 18719  ,U7vmg7SI,MOAnzCbv,NEpONNeA                跨境电子商务业务办理的实施机构是什么   1001.0
# 19348                          NaN              2017美国拉斯维加斯国际大宗商品采购展   1001.0
# 3675                           NaN                    保税仓库设立的审查标准是什么      NaN
# 512                            NaN                    如何办理企业IC卡挂失手续？   1001.0
# 204                            NaN                            你有什么爱好      NaN
# 15133                          NaN                2017 意大利加答国际鞋展（1月）   1001.0
# 15018                          NaN                   第22届华南国际印刷工业展览会   1001.0
# 23694                          NaN                 华夏银行-家和盈86号118天A款   1001.0
# 7189                           NaN  招商银行-高净值专享招银进宝之鼎鼎成金316905号南昌分行销售   1001.0
# 523                            NaN          2014美国拉斯维加斯国际家用纺织品及家居饰品展   1001.0
#
#       kb_type_name
# 18834          NaN
# 10370          NaN
# 13708          NaN
# 1493          图文知识
# 13472          NaN
# 10415          NaN
# 20946          NaN
# 3585           NaN
# 12928          NaN
# 18035          NaN
# 18719          NaN
# 19348          NaN
# 3675          图文知识
# 512            NaN
# 204           图文知识
# 15133          NaN
# 15018          NaN
# 23694          NaN
# 7189           NaN
# 523            NaN

# %%
df_all=df_all.loc[((df_all['kb_type']==1001)|(df_all['kb_type_name']=='图文知识')),['kb_title','kb_content']]

# %%
df_all.shape
# Out:
# (30535, 2)

# %%
df_all=df_all.drop_duplicates()

# %%
df_all.shape
# Out:
# (9747, 2)

# %%
df_all.sample(30)
# Out:
#                              kb_title  \
# 12858       建设银行-乾元鑫溢江南非保本型2018年第828期
# 16647                 减免税备案业务的收费标准是什么
# 21707           交通银行-带你“易”起购 ！苏宁新客满额减
# 1651               加工贸易企业联网监管的审查标准是什么
# 10033    宁波银行-汇通理财2017年惠添利2678号产品宁波专属
# 21575         中国银行-中银稳富ZYWF-GDZH17132
# 1812               华夏银行-增盈1949号161天B款
# 16111               光大银行-【10元惠生活】一起逛逛
# 162                  出口监管仓库延期的申请材料是什么
# 6440            2017 美国拉斯维加斯国际服装及面辅料展
# 3562                海关监管货物仓储审批是什么事项类型
# 16187    民生银行-非凡资产管理翠竹1W理财产品周五高端款314期
# 18177             进口环节代征税补征业务的咨询电话是什么
# 14252         农业银行-金钥匙安心得利2017年第5674期
# 191                    第21华南国际印刷工业展览会
# 6014                 兴业银行-快捷选兴业，积分翻三倍
# 5378               浦发银行-第8期汇理财稳利系列M计划
# 7376       留学人员购买免税国产汽车核准申请业务的监督电话是什么
# 2461       招商银行-高净值专享招银进宝之鼎鼎成金317065号
# 18788                企业信息公示异议的办理形式是什么
# 21770      中国银行-中银平稳智荟系列AMZYPWHQ18867
# 15366                        申报方式有哪些?
# 7152         出口加工区内企业集中申报资格审核的通办范围是什么
# 8454               光大银行-春暖回家路之滴滴机场接送机
# 22354       交通银行-得利宝稳添利拼团1号2441173105
# 9905     民生银行-非凡资产管理翠竹同益1W理财产品周一款031期
# 7595               综合保税区的货物管理的实施机构是什么
# 8493               保税物流中心A型注销的通办范围是什么
# 16539              误卸进口货物管理业务的咨询电话是什么
# 3543   兴业银行-万利宝2018年第1期非保本浮动收益封闭式北京专属
#
#                                               kb_content
# 12858  <table class="comp_tb prd_tb" border="0" cells...
# 16647                                           此业务不需要收费
# 21707  <div class="blkContainerPblk">&#13;\n         ...
# 1651   （一）联网监管资格：<br>\n接收企业申请后，海关主要针对以下内容进行审查评估： <br>...
# 10033  <table class="comp_tb prd_tb" border="0" cells...
# 21575  <table class="comp_tb prd_tb" border="0" cells...
# 1812   <table class="comp_tb prd_tb" border="0" cells...
# 16111  <div class="blkContainerPblk">&#13;\n         ...
# 162    （一）《出口监管仓库申请书》（见附件）、《出口监管仓库设立申请事项表》（见附件）；<br>\...
# 6440   2017 美国拉斯维加斯国际服装及面辅料展<br/>举办地点：拉斯维加斯会议展览中心<br/...
# 3562                                                行政许可
# 16187  <table class="comp_tb prd_tb" border="0" cells...
# 18177                                          各直属海关咨询电话
# 14252  <table class="comp_tb prd_tb" border="0" cells...
# 191    <span style='font-weight:bold;'>第21华南国际印刷工业展览会...
# 6014   <div class="blkContainerPblk">&#13;\n         ...
# 5378   <table class="comp_tb prd_tb" border="0" cells...
# 7376                  各直属海关j监督电话（链接至各直属海关网站）或12360海关服务热线
# 2461   <table class="comp_tb prd_tb" border="0" cells...
# 18788                                               窗口办理
# 21770  <table class="comp_tb prd_tb" border="0" cells...
# 15366                 申报采用电子数据报关单申报方式和纸质报关单申报方式，均具有法律效力。
# 7152                                                  关区
# 8454   <div class="blkContainerPblk">&#13;\n         ...
# 22354  <table class="comp_tb prd_tb" border="0" cells...
# 9905   <table class="comp_tb prd_tb" border="0" cells...
# 7595                             各直属海关、隶属海关负责特殊监管区域业务的部门
# 8493                                                  关区
# 16539                              各直属海关咨询电话或12360海关服务热线
# 3543   <table class="comp_tb prd_tb" border="0" cells...

# %%
def not_empty(s):
    return s and s.strip()
def clean_content(x):
    str_cut=' '.join(re.findall('[\u4e00-\u9fa5]+',str(x)))
    str_cut=jieba.lcut(str_cut)
    str_cut=list(filter(not_empty, str_cut))
    return str_cut

# %%
df_all['kb_content_clean']=df_all['kb_content'].map(clean_content)

# %%
df_all.sample(10)
# Out:
#                               kb_title  \
# 10908            中国银行-中银汇增A计划2018年第26期
# 21937               华夏银行-增盈2036号162天C款
# 3562                 海关监管货物仓储审批是什么事项类型
# 2530             交通银行-甜蜜交通银行 MCAKE免费升磅
# 12099               跨境电子商务业务办理的办理时间是什么
# 2718     民生银行-非凡资产管理翠竹1W理财产品周一对公款特159期
# 11954                 过境货物管理业务的监督电话是什么
# 15619  招商银行-高净值专享金葵花增利系列1202150号北京分行销售
# 684                   出口监管仓库注销的实施机构是什么
# 2010        平安银行-安财富双周利现金管理类2012年2期滚动型
#
#                                               kb_content  \
# 10908  <table class="comp_tb prd_tb" border="0" cells...
# 21937  <table class="comp_tb prd_tb" border="0" cells...
# 3562                                                行政许可
# 2530   <div class="blkContainerPblk">&#13;\n         ...
# 12099                各直属海关业务现场（链接至各直属海关网站）或拨打12361海关服务热线
# 2718   <table class="comp_tb prd_tb" border="0" cells...
# 11954                              各直属海关咨询电话或12361海关服务热线
# 15619  <table class="comp_tb prd_tb" border="0" cells...
# 684                           海关总署加贸司、各直属海关负责出口监管仓库业务的部门
# 2010   <table class="comp_tb prd_tb" border="0" cells...
#
#                                         kb_content_clean
# 10908  [产品名称, 中银, 汇增, 计划, 年, 第, 期, 同类产品, 对比, 同类产品, 对比...
# 21937  [产品名称, 增盈, 号, 天, 款, 同类产品, 对比, 同类产品, 对比, 所属, 银行...
# 3562                                              [行政许可]
# 2530   [新浪, 财经, 信用卡, 优惠活动, 正文, 甜蜜, 交通银行, 免费, 升磅, 年, 月...
# 12099  [各直属, 海关, 业务, 现场, 链接, 至, 各直属, 海关, 网站, 或, 拨打, 海...
# 2718   [产品名称, 非凡, 资产, 管理, 翠竹, 理财产品, 周一, 对, 公款, 特, 期, ...
# 11954                     [各直属, 海关, 咨询电话, 或, 海关, 服务, 热线]
# 15619  [产品名称, 高, 净值, 专享, 金葵花, 增利, 系列, 号, 北京分行, 销售, 同类...
# 684      [海关总署, 加贸司, 各直属, 海关, 负责, 出口, 监管, 仓库, 业务, 的, 部门]
# 2010   [产品名称, 安, 财富, 双周, 利, 现金管理, 类, 年, 期, 滚动, 型, 同类产...

# %%
import re
p='''<p>表头的筛选菜单项object[]-fixed列是否固定，可选 <code>true</code>(等效于 left) <code>'left''right'</code>boolean|stringfalsekeyReact 需要的 key，如果已经设置了唯一的 <code>dataIndex</code>，可以忽略这个属性string-render生成复杂数据的渲染函数，参数分别为当前行的值，当前行数据，行索引，@return里面可以设置表格<a href="https://ant.design/components/table-cn/#components-table-demo-colspan-rowspan" title="行/列合并" target="">行/列合并</a>Function(text, record, index) {}-sorter排序函数，本地排序使用一个函数(参考 <a href="https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/sort" title="Array.sort" target="">Array.sort</a> 的 compareFunction)，需要服务端排序可设为 trueFunction|boolean-sortOrder排序的受控属性，外界可用此控制列的&nbsp;</p>'''
m=' '.join(re.findall('[\u4e00-\u9fa5]+',p))

# %%
m
# Out:
# '表头的筛选菜单项 列是否固定 可选 等效于 需要的 如果已经设置了唯一的 可以忽略这个属性 生成复杂数据的渲染函数 参数分别为当前行的值 当前行数据 行索引 里面可以设置表格 行 列合并 行 列合并 排序函数 本地排序使用一个函数 参考 的 需要服务端排序可设为 排序的受控属性 外界可用此控制列的'

# %%
def not_empty(s):
    return s and s.strip()

# %%
str_cut=jieba.lcut('产品名称 汇通理财 年惠添利 号产品 同类产品对比 同类产品对比 ')

# %%
str_cut=list(filter(not_empty, str_cut))

# %%
str_cut
# Out:
# ['产品名称', '汇通', '理财', '年惠', '添利', '号', '产品', '同类产品', '对比', '同类产品', '对比']

# %%
# Out:
# ['产品名称', '汇通', '理财', '年惠', '添利', '号', '产品', '同类产品', '对比', '同类产品', '对比']

# %%
# !pip install gensim -i https://pypi.douban.com/simple

# %%
df['kb_title_split']=df['kb_title'].map(lambda x:jieba.lcut(str(x)))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.270 seconds.
# Prefix dict has been built succesfully.

# %%
df.head()
# Out:
#                                kb_title  \
# 0                  跨境电子商务企业注册登记的设定依据是什么
# 1  对高层次留学人才回国和海外科技专家来华工作进出境物品业务会办理哪些证件？
# 2           2015年土耳其春季国际家庭用品、礼品及家用电器展览会
# 3                交通银行-得利宝沃德添利2111180013
# 4                   2014 巴西圣保罗环球资源采购交易会
#
#                                           kb_content  \
# 0  《中华人民共和国海关报关单位注册登记管理规定》<br>\n《海关总署关于公布<中华人民共和国...
# 1                                                  无
# 2  <span style='font-weight:bold;'>2015年土耳其春季国际家庭...
# 3  <table class="comp_tb prd_tb" border="0" cells...
# 4  <span style='font-weight:bold;'>2014 巴西圣保罗环球资源...
#
#                                       kb_title_split
# 0           [跨境, 电子商务, 企业, 注册, 登记, 的, 设定, 依据, 是, 什么]
# 1  [对, 高层次, 留学, 人才, 回国, 和, 海外, 科技, 专家, 来华, 工作, 进出...
# 2  [2015, 年, 土耳其, 春季, 国际, 家庭用品, 、, 礼品, 及, 家用电器, 展览会]
# 3                 [交通银行, -, 得利, 宝沃德, 添利, 2111180013]
# 4                [2014,  , 巴西, 圣保罗, 环球, 资源, 采购, 交易会]

# %%
"""准备好训练语料，整理成gensim需要的输入格式"""

train = []
for each in df_all['kb_content_clean']:
    train.append(each)
    # train: [['黄蜂', '湖人', '首发', '科比', '带伤', '战',...],[...],...]

# %%
    
"""构建词频矩阵，训练LDA模型"""
dictionary = corpora.Dictionary(train)
# corpus[0]: [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1),...]
# corpus是把每条新闻ID化后的结果，每个元素是新闻中的每个词语，在字典中的ID和频率
corpus = [dictionary.doc2bow(text) for text in train]

lda = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)
topic_list = lda.print_topics(10)
print("10个主题的单词分布为：\n")
for topic in topic_list:
    print(topic)
# Out:
# 10个主题的单词分布为：
#
# (8, '0.220*"交通银行" + 0.198*"-" + 0.153*"得利" + 0.139*"添利" + 0.048*"宝汇" + 0.042*"宝稳" + 0.034*"汇总" + 0.029*"号" + 0.028*"普通" + 0.026*"美元"')
# (15, '0.140*" " + 0.089*"国际" + 0.088*"）" + 0.088*"（" + 0.088*"博览会" + 0.088*"中国" + 0.086*"家具" + 0.071*"广州" + 0.070*"-" + 0.042*"第一期"')
# (91, '0.140*"工业" + 0.137*"国际" + 0.137*"展览会" + 0.131*"印刷" + 0.131*"华南" + 0.130*"第" + 0.081*"届" + 0.025*"20" + 0.024*"24" + 0.018*"州"')
# (21, '0.148*"办理" + 0.123*"的" + 0.117*"是" + 0.114*"什么" + 0.093*"时间" + 0.078*"形式" + 0.029*"车辆" + 0.028*"港澳" + 0.027*"进出境" + 0.025*"申报"')
# (65, '0.128*"-" + 0.122*"邮储" + 0.100*"银行" + 0.073*"信用卡" + 0.054*"智富" + 0.041*"银联" + 0.041*"消费" + 0.041*"悦享" + 0.035*"分期" + 0.032*" "')
# (53, '0.120*"2013" + 0.082*"用品" + 0.079*"广州" + 0.078*" " + 0.073*"国际" + 0.072*"中国" + 0.068*"及" + 0.068*"展览会" + 0.063*"）" + 0.063*"（"')
# (77, '0.137*"税款" + 0.131*"的" + 0.103*"担保" + 0.093*"什么" + 0.093*"是" + 0.064*"货物" + 0.049*"申请" + 0.045*"提前" + 0.045*"放行" + 0.041*"延期"')
# (67, '0.098*"-" + 0.092*"第" + 0.090*"计划" + 0.082*"理财" + 0.078*"期汇" + 0.076*"系列" + 0.074*"浦发银行" + 0.062*"稳利" + 0.038*"丝路" + 0.026*"11"')
# (52, '0.136*"展" + 0.135*"国际" + 0.135*" " + 0.135*"德国" + 0.135*"纽伦堡" + 0.135*"玩具" + 0.048*"2017" + 0.046*"2015" + 0.043*"2016" + 0.005*"T"')
# (59, '0.176*"？" + 0.144*"申报" + 0.068*"进出境" + 0.067*"多长时间" + 0.057*"的" + 0.049*"是" + 0.043*"行李物品" + 0.043*"货运" + 0.039*"信息" + 0.036*"办理"')

# %%
"""第三步：查看某封邮件所属的主题"""
print("第1封邮件的大致内容为：\n",train[1],'\n')
topic = lda.get_document_topics(corpus[1])
print("第1封邮件的主题分布为：\n",topic,'\n')
# Out:
# 第1封邮件的大致内容为：
#  ['对', '高层次', '留学', '人才', '回国', '和', '海外', '科技', '专家', '来华', '工作', '进出境', '物品', '业务', '会', '办理', '哪些', '证件', '？']
#
# 第1封邮件的主题分布为：
#  [(4, 0.779479), (8, 0.13051625), (9, 0.055000674)]

# %%
# 第三步：抽取新闻的主题
# 我们还可以利用训练好的LDA，得到一条新闻的主题分布，也就是一条新闻属于各主题的可能性的概率分布
# 新闻ID化    
test=[]
content_t=['中国人民银行外汇储备高达上万亿','海关手续如何办理','遭遇不法分子袭击怎么办']
for each in content_t:
    test.append(jieba.lcut(each))
    
corpus_test = [dictionary.doc2bow(text) for text in test]
# 得到每条新闻的主题分布
topics_test = lda.get_document_topics(corpus_test)  
labels = ['经济','办理手续','其它']
for i in range(3):
    print('这条'+labels[i]+'新闻的主题分布为：\n')
    print(sorted(topics_test[i],key=lambda item:item[1],reverse=True),'\n')
# Out:
# 这条经济新闻的主题分布为：
#
# [(2, 0.5568314), (8, 0.049243666), (4, 0.049241006), (7, 0.049240638), (9, 0.049240615), (0, 0.049240608), (3, 0.049240522), (5, 0.0492405), (6, 0.0492405), (1, 0.04924048)]
#
# 这条办理手续新闻的主题分布为：
#
# [(8, 0.5711329), (2, 0.26885617), (4, 0.020002102), (7, 0.020001322), (3, 0.020001262), (0, 0.02000125), (1, 0.02000125), (5, 0.02000125), (6, 0.02000125), (9, 0.02000125)]
#
# 这条其它新闻的主题分布为：
#
# [(7, 0.54985714), (0, 0.050015874), (1, 0.050015874), (2, 0.050015874), (3, 0.050015874), (4, 0.050015874), (5, 0.050015874), (6, 0.050015874), (8, 0.050015874), (9, 0.050015874)]

# %%
################################33
# 利用word2vec进行处理

# %%
# import modules & set up logging
import logging
import os
from gensim.models import word2vec

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# sentences = word2vec.LineSentence('./in_the_name_of_people_segment.txt') 

model = word2vec.Word2Vec(train, hs=1,min_count=1,window=5,size=200)
# Out:
# 2019-07-20 07:54:07,910 : INFO : collecting all words and their counts
# 2019-07-20 07:54:07,913 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-07-20 07:54:08,161 : INFO : collected 18028 word types from a corpus of 1005863 raw words and 9747 sentences
# 2019-07-20 07:54:08,162 : INFO : Loading a fresh vocabulary
# 2019-07-20 07:54:08,343 : INFO : effective_min_count=1 retains 18028 unique words (100% of original 18028, drops 0)
# 2019-07-20 07:54:08,344 : INFO : effective_min_count=1 leaves 1005863 word corpus (100% of original 1005863, drops 0)
# 2019-07-20 07:54:08,486 : INFO : deleting the raw counts dictionary of 18028 items
# 2019-07-20 07:54:08,487 : INFO : sample=0.001 downsamples 60 most-common words
# 2019-07-20 07:54:08,488 : INFO : downsampling leaves estimated 787284 word corpus (78.3% of prior 1005863)
# 2019-07-20 07:54:08,515 : INFO : constructing a huffman tree from 18028 words
# 2019-07-20 07:54:09,487 : INFO : built huffman tree with maximum node depth 20
# 2019-07-20 07:54:09,549 : INFO : estimated required memory for 18028 words and 200 dimensions: 55886800 bytes
# 2019-07-20 07:54:09,551 : INFO : resetting layer weights
# 2019-07-20 07:54:10,085 : INFO : training model with 3 workers on 18028 vocabulary and 200 features, using sg=0 hs=1 sample=0.001 negative=5 window=5
# 2019-07-20 07:54:11,109 : INFO : EPOCH 1 - PROGRESS: at 26.46% examples, 215355 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:12,122 : INFO : EPOCH 1 - PROGRESS: at 57.43% examples, 227824 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:13,155 : INFO : EPOCH 1 - PROGRESS: at 89.48% examples, 229106 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:13,446 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-20 07:54:13,475 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-20 07:54:13,485 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-20 07:54:13,486 : INFO : EPOCH - 1 : training on 1005863 raw words (786580 effective words) took 3.4s, 231710 effective words/s
# 2019-07-20 07:54:14,544 : INFO : EPOCH 2 - PROGRESS: at 27.17% examples, 216786 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:15,547 : INFO : EPOCH 2 - PROGRESS: at 59.65% examples, 233127 words/s, in_qsize 6, out_qsize 0
# 2019-07-20 07:54:16,553 : INFO : EPOCH 2 - PROGRESS: at 91.82% examples, 237393 words/s, in_qsize 6, out_qsize 0
# 2019-07-20 07:54:16,740 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-20 07:54:16,746 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-20 07:54:16,754 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-20 07:54:16,755 : INFO : EPOCH - 2 : training on 1005863 raw words (787842 effective words) took 3.3s, 241620 effective words/s
# 2019-07-20 07:54:17,773 : INFO : EPOCH 3 - PROGRESS: at 26.19% examples, 216747 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:18,807 : INFO : EPOCH 3 - PROGRESS: at 60.48% examples, 237215 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:19,808 : INFO : EPOCH 3 - PROGRESS: at 93.73% examples, 242936 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:19,944 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-20 07:54:19,956 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-20 07:54:19,980 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-20 07:54:19,981 : INFO : EPOCH - 3 : training on 1005863 raw words (786916 effective words) took 3.2s, 244402 effective words/s
# 2019-07-20 07:54:20,999 : INFO : EPOCH 4 - PROGRESS: at 29.22% examples, 239195 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:22,036 : INFO : EPOCH 4 - PROGRESS: at 62.16% examples, 244094 words/s, in_qsize 3, out_qsize 2
# 2019-07-20 07:54:23,050 : INFO : EPOCH 4 - PROGRESS: at 95.40% examples, 246534 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:23,108 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-20 07:54:23,134 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-20 07:54:23,139 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-20 07:54:23,141 : INFO : EPOCH - 4 : training on 1005863 raw words (787209 effective words) took 3.2s, 249426 effective words/s
# 2019-07-20 07:54:24,159 : INFO : EPOCH 5 - PROGRESS: at 27.80% examples, 233016 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:25,185 : INFO : EPOCH 5 - PROGRESS: at 61.31% examples, 242188 words/s, in_qsize 5, out_qsize 0
# 2019-07-20 07:54:26,186 : INFO : EPOCH 5 - PROGRESS: at 91.93% examples, 238674 words/s, in_qsize 4, out_qsize 1
# 2019-07-20 07:54:26,316 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-07-20 07:54:26,353 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-07-20 07:54:26,361 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-07-20 07:54:26,363 : INFO : EPOCH - 5 : training on 1005863 raw words (787545 effective words) took 3.2s, 244935 effective words/s
# 2019-07-20 07:54:26,364 : INFO : training on a 5029315 raw words (3936092 effective words) took 16.3s, 241809 effective words/s

# %%
# 保存模型，以便重用
# model.save(u"computer.model")
# 对应的加载方式
# model_2 = word2vec.Word2Vec.load("text8.model")

# 以一种C语言可以解析的形式存储词向量
# model.save_word2vec_format(u"computer.model.bin", binary=True)
# 对应的加载方式
# model_3 = word2vec.Word2Vec.load_word2vec_format("text8.model.bin", binary=True)

# %%
# 第一个是最常用的，找出某一个词向量最相近的词集合，代码如下：
req_count = 20
for key in model.wv.similar_by_word('展览会', topn =100):
    if len(key[0])==3:
        req_count -= 1
        print (key[0], key[1])
        if req_count == 0:
            break;
# Out:
# 博览会 0.7610650658607483
# 影响力 0.5831416845321655
# 土耳其 0.5729050636291504
# 广交会 0.515791654586792
# 纺织品 0.4987368583679199
# 消费品 0.4793652594089508
# 自动化 0.4589780867099762
# 纸制品 0.44146299362182617
# 交易会 0.4404833912849426
# 出发点 0.431710422039032
# 圣保罗 0.43011611700057983
# 含金量 0.4241924285888672
# 制造商 0.42052632570266724
# 非中文 0.418093740940094
# 装饰品 0.41488468647003174

# %%
# 第二个应用是看两个词向量的相近程度，这里给出了书中两组人的相似程度：

# %%
print (model.wv.similarity('政策', '税收'))
print (model.wv.similarity('日本', '中国'))
# Out:
# 0.4749853
# 0.15439937

# %%
# 第三个应用是找出不同类的词，这里给出了人物分类题：

# %%
print (model.wv.doesnt_match("浦发银行 税收 海关 ".split()))
# Out:
# 浦发银行
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
#获取model里面的说有关键词
keys=model.wv.vocab.keys()

# print(keys)
from sklearn.cluster import KMeans
#获取词对于的词向量
wordvector=[]
for key in keys:
    wordvector.append(model[key])

#分类
clf = KMeans(n_clusters=200)
s = clf.fit(wordvector)
print (s)
#获取到所有词向量所属类别
labels=clf.labels_
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=200, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
keys=list(keys)

# %%
print(labels)
# Out:
# [ 21 102  63 ...   0   0  71]

# %%
#把是一类的放入到一个集合
classCollects={}
for i in range(len(keys)):
    if labels[i] in classCollects.keys():
        classCollects[labels[i]].append(keys[i])
    else:
        classCollects[labels[i]]=[keys[i]]

# %%
for each in classCollects:
    print(each,len(classCollects[each]))
# Out:
# 0 375
# 1 68
# 2 5
# 3 3
# 4 25
# 5 448
# 6 203
# 7 157
# 8 4
# 9 12
# 10 178
# 11 43
# 12 1
# 13 28
# 14 167
# 15 1
# 16 5
# 17 1
# 18 3
# 19 47
# 20 680
# 21 48
# 22 2
# 23 5
# 24 19
# 25 37
# 26 620
# 27 156
# 28 52
# 29 4
# 30 36
# 31 30
# 32 153
# 33 7
# 34 10
# 35 25
# 36 150
# 37 14
# 38 355
# 39 5
# 40 52
# 41 9
# 42 21
# 43 29
# 44 77
# 45 1
# 46 1
# 47 1
# 48 1
# 49 1
# 50 1
# 51 5
# 52 13
# 53 469
# 54 11
# 55 1
# 56 2
# 57 37
# 58 1
# 59 18
# 60 4
# 61 3
# 62 1
# 63 1571
# 64 1
# 65 162
# 66 25
# 67 3
# 68 16
# 69 19
# 70 31
# 71 4028
# 72 7
# 73 67
# 74 8
# 75 1
# 76 5
# 77 1
# 78 1
# 79 27
# 80 9
# 81 1
# 82 202
# 83 17
# 84 22
# 85 34
# 86 3
# 87 91
# 88 1
# 89 16
# 90 233
# 91 1
# 92 1
# 93 1
# 94 16
# 95 1
# 96 8
# 97 20
# 98 1
# 99 8
# 100 506
# 101 1
# 102 4270
# 103 22
# 104 1
# 105 12
# 106 6
# 107 49
# 108 28
# 109 1
# 110 69
# 111 4
# 112 1
# 113 9
# 114 1
# 115 1
# 116 14
# 117 25
# 118 91
# 119 2
# 120 1
# 121 1
# 122 39
# 123 1
# 124 43
# 125 42
# 126 1
# 127 4
# 128 1
# 129 12
# 130 1
# 131 1
# 132 1
# 133 5
# 134 89
# 135 1
# 136 246
# 137 1
# 138 4
# 139 4
# 140 1
# 141 32
# 142 20
# 143 1
# 144 52
# 145 1
# 146 1
# 147 37
# 148 1
# 149 2
# 150 1
# 151 1
# 152 2
# 153 1
# 154 1
# 155 1
# 156 8
# 157 2
# 158 1
# 159 9
# 160 7
# 161 1
# 162 12
# 163 1
# 164 8
# 165 3
# 166 1
# 167 1
# 168 1
# 169 1
# 170 1
# 171 1
# 172 1
# 173 1
# 174 1
# 175 1
# 176 15
# 177 149
# 178 85
# 179 95
# 180 19
# 181 7
# 182 89
# 183 1
# 184 5
# 185 1
# 186 1
# 187 20
# 188 2
# 189 1
# 190 69
# 191 1
# 192 1
# 193 1
# 194 1
# 195 1
# 196 23
# 197 1
# 198 1
# 199 11

# %%
from   collections import OrderedDict

# %%
classCollects[0]
# Out:
# ['日利率',
#  '九鼎',
#  '证正',
#  '提车',
#  '餐馆',
#  '建议您',
#  '单立',
#  '签单',
#  '贴示',
#  '石材',
#  '签购',
#  '更多',
#  '怀柔',
#  '已近',
#  '龙华',
#  '合伙人',
#  '悦城',
#  '限到',
#  '慢湘',
#  '持多张',
#  '含海',
#  '不夜城',
#  '非该',
#  '明珠',
#  '平度',
#  '天得玉',
#  '按摩',
#  '美洲地区',
#  '到手',
#  '短',
#  '天神',
#  '必争',
#  '一卡通',
#  '拖欠',
#  '旗舰',
#  '自本',
#  '于店',
#  '输项',
#  '尽',
#  '重庆地区',
#  '欢唱',
#  '底商',
#  '爆发',
#  '清关',
#  '不足以',
#  '百夫长',
#  '消耗',
#  '未持',
#  '天时',
#  '房型',
#  '佳明',
#  '橙子',
#  '彭城',
#  '东盛',
#  '鲁商',
#  '款中',
#  '内文宣',
#  '地铁票',
#  '周限享',
#  '车票',
#  '宝惠盈',
#  '差价',
#  '不含税',
#  '南楼',
#  '只供',
#  '失卡',
#  '代码证',
#  '斯特',
#  '货主',
#  '游戏机',
#  '棉花',
#  '一并',
#  '如是',
#  '横滨',
#  '发电机',
#  '长期有效',
#  '清水',
#  '东北',
#  '游记',
#  '装船',
#  '市级',
#  '聚集',
#  '专人',
#  '卡后',
#  '托运',
#  '奥克斯',
#  '售罄',
#  '一日',
#  '铺位',
#  '盈第',
#  '水疗',
#  '查明',
#  '支出',
#  '逸贷',
#  '隔热材料',
#  '京都',
#  '离境',
#  '备注',
#  '名店',
#  '围裙',
#  '便宜',
#  '市中心',
#  '小路',
#  '羽毛球',
#  '突显',
#  '服务业',
#  '公证书',
#  '几分钟',
#  '免密',
#  '下旬',
#  '及立',
#  '文昌',
#  '香溢',
#  '代付',
#  '京',
#  '扬声器',
#  '特定',
#  '波兰',
#  '覆盖全国',
#  '特卖',
#  '不饱和',
#  '享满',
#  '由该',
#  '全退',
#  '春',
#  '来看',
#  '南航',
#  '龙岗区',
#  '妩',
#  '减则',
#  '爱牙享',
#  '上规模',
#  '有舱',
#  '做成',
#  '畅打',
#  '福柚',
#  '发送给',
#  '高知',
#  '金河',
#  '小盒',
#  '付通',
#  '八角',
#  '提醒您',
#  '早',
#  '经营者',
#  '上立',
#  '提供商',
#  '隆为',
#  '黄边',
#  '皓月',
#  '之星',
#  '多尊',
#  '静冈县',
#  '世家',
#  '高品质',
#  '布放',
#  '天通苑',
#  '如退',
#  '折页',
#  '加贸',
#  '即墨',
#  '看上去',
#  '即该',
#  '豪礼',
#  '最差',
#  '扎根',
#  '天涯',
#  '顿掘',
#  '台历',
#  '宋渡',
#  '发新户',
#  '任性',
#  '以为',
#  '比较',
#  '深层',
#  '取悦',
#  '苏坡',
#  '顾客',
#  '两',
#  '变',
#  '新人',
#  '青森县',
#  '再刷',
#  '百付',
#  '粒',
#  '上海地区',
#  '国际化',
#  '越高',
#  '天府广场',
#  '男士',
#  '美甲',
#  '员',
#  '头等舱',
#  '贵州',
#  '爆品',
#  '京津',
#  '罗湖区',
#  '省级',
#  '计为',
#  '定居',
#  '仁川',
#  '裕锦园',
#  '满立',
#  '订购',
#  '变形金刚',
#  '花生',
#  '马哥',
#  '寄卖品',
#  '一点',
#  '一台',
#  '雀巢',
#  '出站',
#  '鹤山',
#  '总府路',
#  '横',
#  '儿童医院',
#  '他行',
#  '区分',
#  '可折叠',
#  '弘前',
#  '天成',
#  '明洞',
#  '参照',
#  '签章',
#  '香槟',
#  '非银行',
#  '黄人',
#  '转赠',
#  '含微信',
#  '内含',
#  '签订',
#  '不全',
#  '过关',
#  '金普卡及',
#  '芝麻',
#  '记得',
#  '行员',
#  '供货',
#  '复活节',
#  '大洋',
#  '信使',
#  '提起',
#  '白石',
#  '兰桂坊',
#  '管理体系',
#  '需凭',
#  '点满',
#  '不补',
#  '较慢',
#  '雨靴',
#  '大片',
#  '一次性',
#  '上海海关',
#  '抵减',
#  '一对',
#  '凯丹店',
#  '白云',
#  '赤坎',
#  '点整',
#  '未立',
#  '礼物',
#  '明月刀',
#  '青睐',
#  '铜锣湾',
#  '特指',
#  '页数',
#  '长丰',
#  '金融机构',
#  '牛王庙',
#  '待定',
#  '前夜',
#  '节节',
#  '容桂',
#  '总府',
#  '便捷',
#  '袖扣',
#  '正在',
#  '巷子',
#  '速度',
#  '入台证',
#  '二星',
#  '全球性',
#  '停放',
#  '月限享',
#  '搜狐',
#  '家庄',
#  '华艺',
#  '大石',
#  '单独',
#  '其次',
#  '凭以',
#  '倾力',
#  '非必',
#  '雪票',
#  '万减',
#  '局',
#  '乐天',
#  '关闭',
#  '零碳',
#  '別府',
#  '制造业',
#  '颗',
#  '含财',
#  '先端',
#  '大厨',
#  '即能',
#  '财智',
#  '飞轮',
#  '高知店',
#  '太升',
#  '英文翻译',
#  '乃至',
#  '停线',
#  '预付',
#  '鹤山市',
#  '面包',
#  '新加坡元',
#  '旅行包',
#  '愿望',
#  '本体',
#  '保姆',
#  '双年',
#  '主卡及',
#  '深航',
#  '单年',
#  '千叶县',
#  '投',
#  '折上',
#  '欢乐城',
#  '锦里',
#  '前进',
#  '红莲',
#  '高志',
#  '登机牌',
#  '缔造',
#  '仅为',
#  '凯德',
#  '业务联系',
#  '闽江路',
#  '上网',
#  '及陀',
#  '师宏运来',
#  '和歌山',
#  '科技前沿',
#  '玉龙',
#  '享免',
#  '宋先生',
#  '准购',
#  '届时',
#  '月限前',
#  '办卡赠',
#  '绑卡',
#  '英尺',
#  '盐田区',
#  '同',
#  '小提示',
#  '东城',
#  '定点',
#  '审结',
#  '北楼',
#  '静冈',
#  '攻略',
#  '信心',
#  '框',
#  '长盈',
#  '张满',
#  '台场',
#  '尽早',
#  '宠大',
#  '索菲特',
#  '童子',
#  '生婴儿',
#  '纪念品',
#  '第四部',
#  '限售']

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
 

'利用SSE选择k'
SSE = []  # 存放每次结果的误差平方和
for k in range(1,20):
    print('k={}'.format(k))
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(wordvector)
    SSE.append(estimator.inertia_) # estimator.inertia_获取聚类准则的总和
X = range(1,20)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(X,SSE,'o-')
plt.show()
# Out:
# k=1
# k=2
# k=3
# k=4
# k=5
# k=6
# k=7
# k=8
# k=9
# k=10
# k=11
# k=12
# k=13
# k=14
# k=15
# k=16
# k=17
# k=18
# k=19
